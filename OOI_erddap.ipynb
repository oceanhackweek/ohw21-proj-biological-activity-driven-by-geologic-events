# %% [markdown]
# ## Reading OOI Regional Cabled Array data for the 2015 Axial Seamount eruption event
# https://dataexplorer.oceanobservatories.org/#ooi/array/RS/subsite/RS03AXBS/overview?sort=end_time_desc&instrument_id=RS03AXBS-LJ03A-05-HPIESA301
#
# Data include: Axial base seafloor and Axial Base Shallow Profiler Mooring (200m)
#
# Axial Base Deep Profiler Mooring is **not** available for some reason

# %%
import xarray as xr
from erddapy import ERDDAP
from datetime import datetime,timedelta
import numpy as np

# %%
server = "https://erddap.dataexplorer.oceanobservatories.org/erddap"
e = ERDDAP(server=server, protocol="tabledap")

# %%
def fix_date(da):
    da = da.assign(time=([datetime(1970,1,1) + timedelta(seconds=second) for second in da.time.data]))
    return da

# %% [markdown]
# ## Axial Base Seafloor

# %%
e.dataset_id = ("ooi-rs03axbs-lj03a-05-hpiesa301")
e.variables = [
    'time', 
    'latitude',
    'longitude',
    'z',
    'iespres'
]
seafloor = e.to_xarray(decode_times=False)
seafloor = fix_date(seafloor)
seafloor
# Out:
# <xarray.Dataset>
# Dimensions:    (timeseries: 1, time: 301587, obs: 301587)
# Coordinates:
#     latitude   (timeseries) float64 ...
#     longitude  (timeseries) float64 ...
#   * time       (time) datetime64[ns] 2014-08-22T22:52:00 ... 2021-08-03T00:45:00
# Dimensions without coordinates: timeseries, obs
# Data variables:
#     station    (timeseries) object ...
#     rowSize    (timeseries) int32 ...
#     z          (obs) float64 ...
#     iespres    (obs) float64 ...
# Attributes: (12/50)
#     cdm_data_type:                 TimeSeries
#     cdm_timeseries_variables:      station,longitude,latitude
#     contributor_email:             feedback@axiomdatascience.com
#     contributor_name:              Axiom Data Science
#     contributor_role:              processor
#     contributor_role_vocabulary:   NERC
#     ...                            ...
#     station_id:                    104306
#     summary:                       Timeseries data from 'Regional Cabled Arra...
#     time_coverage_end:             2021-08-03T00:45:00Z
#     time_coverage_start:           2014-08-22T22:52:00Z
#     title:                         Regional Cabled Array: Axial Base Seafloor...
#     Westernmost_Easting:           -129.75995

# %% [markdown]
# ## Axial Base Shallow Profiler Mooring (200m)
# ### Chlorophyll

# %%
e.dataset_id = ("ooi-rs03axps-pc03a-4c-flordd303")
e.variables = [
    'time',
    'z',
    'latitude',
    'longitude',
    'cdomflo',
    'mass_concentration_of_chlorophyll_a_in_sea_water',
    'flubsct'
]
shallow_chl = e.to_xarray(decode_times=False)
shallow_chl = fix_date(shallow_chl)
shallow_chl
# Out:
# <xarray.Dataset>
# Dimensions:                                           (timeseries: 1, time: 2900722, obs: 2900722)
# Coordinates:
#     latitude                                          (timeseries) float64 ...
#     longitude                                         (timeseries) float64 ...
#   * time                                              (time) datetime64[ns] 2...
# Dimensions without coordinates: timeseries, obs
# Data variables:
#     station                                           (timeseries) object ...
#     rowSize                                           (timeseries) int32 ...
#     z                                                 (obs) float64 ...
#     cdomflo                                           (obs) float64 ...
#     mass_concentration_of_chlorophyll_a_in_sea_water  (obs) float64 ...
#     flubsct                                           (obs) float64 ...
# Attributes: (12/50)
#     cdm_data_type:                 TimeSeries
#     cdm_timeseries_variables:      station,longitude,latitude
#     contributor_email:             feedback@axiomdatascience.com
#     contributor_name:              Axiom Data Science
#     contributor_role:              processor
#     contributor_role_vocabulary:   NERC
#     ...                            ...
#     station_id:                    104322
#     summary:                       Timeseries data from 'Regional Cabled Arra...
#     time_coverage_end:             2021-08-02T23:59:00Z
#     time_coverage_start:           2014-10-02T12:38:00Z
#     title:                         Regional Cabled Array: Axial Base Shallow ...
#     Westernmost_Easting:           -129.75326

# %% [markdown]
# ## CTD

# %%
e.dataset_id = ("ooi-rs03axps-pc03a-4a-ctdpfa303")
e.variables = [
    'time',
    'z',
    'latitude',
    'longitude',
    'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
    'moles_of_oxygen_per_unit_mass_in_sea_water',
    'sea_water_practical_salinity',
    'sea_water_density',
    'sea_water_pressure',
    'sea_water_temperature'
]
shallow_ctd = e.to_xarray(decode_times=False)
shallow_ctd = fix_date(shallow_ctd)
shallow_ctd
# Out:
# <xarray.Dataset>
# Dimensions:                                                        (timeseries: 1, time: 2979794, obs: 2979794)
# Coordinates:
#     latitude                                                       (timeseries) float64 ...
#     longitude                                                      (timeseries) float64 ...
#   * time                                                           (time) datetime64[ns] ...
# Dimensions without coordinates: timeseries, obs
# Data variables:
#     station                                                        (timeseries) object ...
#     rowSize                                                        (timeseries) int32 ...
#     z                                                              (obs) float64 ...
#     mole_concentration_of_dissolved_molecular_oxygen_in_sea_water  (obs) float64 ...
#     moles_of_oxygen_per_unit_mass_in_sea_water                     (obs) float64 ...
#     sea_water_practical_salinity                                   (obs) float64 ...
#     sea_water_density                                              (obs) float64 ...
#     sea_water_pressure                                             (obs) float64 ...
#     sea_water_temperature                                          (obs) float64 ...
# Attributes: (12/50)
#     cdm_data_type:                 TimeSeries
#     cdm_timeseries_variables:      station,longitude,latitude
#     contributor_email:             feedback@axiomdatascience.com
#     contributor_name:              Axiom Data Science
#     contributor_role:              processor
#     contributor_role_vocabulary:   NERC
#     ...                            ...
#     station_id:                    104319
#     summary:                       Timeseries data from 'Regional Cabled Arra...
#     time_coverage_end:             2021-08-02T23:59:00Z
#     time_coverage_start:           2014-10-02T20:42:00Z
#     title:                         Regional Cabled Array: Axial Base Shallow ...
#     Westernmost_Easting:           -129.75326

# %% [markdown]
# ## pH

# %%
e.dataset_id = ("ooi-rs03axps-pc03a-4b-phsena302")
e.variables = [
    'time',
    'z',
    'latitude',
    'longitude',
    'sea_water_ph_reported_on_total_scale'
]
shallow_ph = e.to_xarray(decode_times=False)
shallow_ph = fix_date(shallow_ph)
shallow_ph
# Out:
# <xarray.Dataset>
# Dimensions:                               (timeseries: 1, time: 34484, obs: 34484)
# Coordinates:
#     latitude                              (timeseries) float64 ...
#     longitude                             (timeseries) float64 ...
#   * time                                  (time) datetime64[ns] 2014-10-03 .....
# Dimensions without coordinates: timeseries, obs
# Data variables:
#     station                               (timeseries) object ...
#     rowSize                               (timeseries) int32 ...
#     z                                     (obs) float64 ...
#     sea_water_ph_reported_on_total_scale  (obs) float64 ...
# Attributes: (12/50)
#     cdm_data_type:                 TimeSeries
#     cdm_timeseries_variables:      station,longitude,latitude
#     contributor_email:             feedback@axiomdatascience.com
#     contributor_name:              Axiom Data Science
#     contributor_role:              processor
#     contributor_role_vocabulary:   NERC
#     ...                            ...
#     station_id:                    104321
#     summary:                       Timeseries data from 'Regional Cabled Arra...
#     time_coverage_end:             2021-07-17T05:00:00Z
#     time_coverage_start:           2014-10-03T00:00:00Z
#     title:                         Regional Cabled Array: Axial Base Shallow ...
#     Westernmost_Easting:           -129.75326

# %% [markdown]
# ## Velocity

# %%
e.dataset_id = ("ooi-rs03axps-pc03a-05-adcptd302")
e.variables = [
    'time',
    'z',
    'latitude',
    'longitude',
    'eastward_sea_water_velocity',
    'northward_sea_water_velocity',
    'upward_sea_water_velocity'
]
shallow_vel = e.to_xarray(decode_times=False)
shallow_vel = fix_date(shallow_vel)
shallow_vel
# Out:
# <xarray.Dataset>
# Dimensions:                       (timeseries: 1, time: 110029, profile: 110029, obs: 33668874)
# Coordinates:
#     latitude                      (timeseries) float64 ...
#     longitude                     (timeseries) float64 ...
#   * time                          (time) datetime64[ns] 2014-10-02T20:55:00 ....
#     z                             (obs) float64 ...
# Dimensions without coordinates: timeseries, profile, obs
# Data variables:
#     station                       (timeseries) object ...
#     timeseriesIndex               (profile) int32 ...
#     rowSize                       (profile) int32 ...
#     eastward_sea_water_velocity   (obs) float64 ...
#     northward_sea_water_velocity  (obs) float64 ...
#     upward_sea_water_velocity     (obs) float64 ...
# Attributes: (12/52)
#     cdm_altitude_proxy:            z
#     cdm_data_type:                 TimeSeriesProfile
#     cdm_profile_variables:         time
#     cdm_timeseries_variables:      station,longitude,latitude
#     contributor_email:             feedback@axiomdatascience.com
#     contributor_name:              Axiom Data Science
#     ...                            ...
#     station_id:                    104317.0
#     summary:                       Timeseries data from 'Regional Cabled Arra...
#     time_coverage_end:             2014-12-31T23:59:00Z
#     time_coverage_start:           2014-10-02T20:55:00Z
#     title:                         Regional Cabled Array: Axial Base Shallow ...
#     Westernmost_Easting:           -129.75326

# %% [markdown]
# ## Save to netcdf

# %%
seafloor.to_netcdf('seafloor.nc')
shallow_chl.to_netcdf('shallow_chl.nc')
shallow_ctd.to_netcdf('shallow_ctd.nc')
shallow_ph.to_netcdf('shallow_ph.nc')
shallow_vel.to_netcdf('shallow_vel.nc')
